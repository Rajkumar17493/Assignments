# %% [markdown]
# Q1 : A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units. A randomly selected sample of cutlets was collected from both units and measured? Analyze the data and draw inferences at 5% significance level. Please state the assumptions and tests that you carried out to check validity of the assumptions.

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\836916\\Documents\\Python\\Notebook'

# %%
cutlets=pd.read_csv("C:\\Users\\836916\\Documents\\Python\\Notebook\\Untitled Folder\\cutlets.csv")

# %%
cutlets.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
from scipy import stats

# %%
stats.ttest_ind(cutlets['Unit A'], cutlets['Unit B'], alternative='two-sided')
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %% [raw]
# HYPOTHESIS
# **********
# Ho : There is no significant difference in diameter of cutlets
# Ha : There is significant difference in diameter of cutlets
# SOLUTION
# ********
# alpha : 0.05
# pvalue found : 0.47
# pvalue is greater than alpha, Hence Ho is failed to reject
# CONCLUSION
# **********
# There is no significant difference in diameter of cutlets.

# %% [markdown]
# Q2. A hospital wants to determine whether there is any difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list. They collected a random sample and recorded TAT for reports of 4 laboratories. TAT is defined as sample collected to report dispatch.
#
#   Analyze the data and determine whether there is any difference in average TAT among the different laboratories at 5% significance level.

# %%
lab=pd.read_csv("C:\\Users\\836916\\Documents\\Python\\Notebook\\Untitled Folder\\LabTAT.csv")

# %%
lab.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
stats.f_oneway(lab['Laboratory 1'],lab['Laboratory 2'],lab['Laboratory 3'],lab['Laboratory 4'])
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %% [raw]
# HYPOTHESIS
# **********
# Ho : There is no difference in the average Turn Around Time (TAT) of reports
# Ha : There is any difference in the average Turn Around Time (TAT) of reports
# SOLUTION
# ********
# alpha : 0.05
# pvalue found : 2.1156708949992414e-57
# pvalue is lesser than alpha, Hence Ho is rejected
# CONCLUSION
# **********
# There is any difference in the average Turn Around Time (TAT) of reports

# %% [markdown]
# Q3

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %%
buyer_ratio=pd.read_csv("C:\\Users\\836916\\Documents\\Python\\Notebook\\Untitled Folder\\BuyerRatio.csv")

# %%
buyer_ratio=buyer_ratio.drop('Observed Values',axis=1)

# %%
observed=buyer_ratio.to_numpy()

# %%
stat,pvalue,dof,expected=stats.chi2_contingency(observed)

# %%
print(stat,pvalue,dof,expected)
# Out:
# 1.595945538661058 0.6603094907091882 3 [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %% [raw]
# HYPOTHESIS
# **********
# Ho : All proportions are equal
# Ha : Not all proportions are equal
# Observed = [[50,142,131,70],[435,1523,1356,750]]
# SOLUTION
# ********
# Expected = [[  42.76531299  146.81287862  131.11756787   72.30424052][ 442.23468701 1518.18712138 1355.88243213  747.69575948]]
# p value = 0.66
# alpha = 0.05
# p value is greater than alpha. Hence Ho is failed to reject.
# CONCLUSION
# **********
# All proportions are equal.

# %% [markdown]
# Q4. TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain %  of the customer order forms. Any error in order form renders it defective and has to be reworked before processing.  The manager wants to check whether the defective %  varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences

# %%
df=pd.read_csv("C:\\Users\\836916\\Documents\\Python\\Notebook\\Untitled Folder\\Costomer+OrderForm.csv")

# %%
df.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
df1=df.apply(pd.Series.value_counts)

# %%
df1
# Out:
#             Phillippines  Indonesia  Malta  India
# Error Free           271        267    269    280
# Defective             29         33     31     20

# %%
observed=df1.to_numpy()

# %%
observed
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]], dtype=int64)

# %%
stat,p,dof,expected=stats.chi2_contingency(observed)

# %%
print(stat,p,dof,expected)
# Out:
# 3.858960685820355 0.2771020991233135 3 [[271.75 271.75 271.75 271.75]
#  [ 28.25  28.25  28.25  28.25]]

# %% [raw]
# HYPOTHESIS
# **********
# Ho : defective % does not vary by centre
# Ha : defective % varies by centre
# Observed = [[271, 267, 269, 280],[ 29,  33,  31,  20]]
# SOLUTION
# ********
# Expected = [[271.75 271.75 271.75 271.75] [ 28.25  28.25  28.25  28.25]]
# p value = 0.27
# alpha = 0.05
# p value is greater than alpha. Hence Ho is failed to reject.
# CONCLUSION
# **********
# defective % does not vary by centre
