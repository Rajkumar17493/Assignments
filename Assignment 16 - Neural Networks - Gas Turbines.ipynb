# %% [markdown]
# ## Problem Statement
#
# The dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine.
# The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
# Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.

# %% [markdown]
# ### Import Libraries

# %%
#pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org scikeras

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold,train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import softmax,relu,sigmoid
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.losses import BinaryCrossentropy,MeanSquaredError,MeanAbsoluteError,MeanAbsolutePercentageError
from scikeras.wrappers import KerasRegressor

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data

# %%
gt=pd.read_csv('..\\may 5 batch codes\\Data files\\gas_turbines.csv')
gt.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %% [markdown]
# ### Data Understanding

# %%
gt.shape
# Out:
# (15039, 11)

# %%
gt.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
gt.dtypes
# Out:
# AT      float64
# AP      float64
# AH      float64
# AFDP    float64
# GTEP    float64
# TIT     float64
# TAT     float64
# TEY     float64
# CDP     float64
# CO      float64
# NOX     float64
# dtype: object

# %%
gt[gt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Dist and Box Plots for Features (Continuous Data)

# %%
for i in gt.columns:
    print(i)
    plt.figure(figsize=(15,4))
    sns.boxplot(gt[i])
    plt.show()
# Out:
# AT
# AP
# AH
# AFDP
# GTEP
# TIT
# TAT
# TEY
# CDP
# CO
# NOX

# %%
for i in gt.columns:
    print(i)
    gt[i].plot(kind='kde')
    plt.show()
# Out:
# AT
# AP
# AH
# AFDP
# GTEP
# TIT
# TAT
# TEY
# CDP
# CO
# NOX

# %%
gt.hist(figsize=(15,15),)
plt.show()

# %%
#Correlation Metrics
corr=gt.corr().round(2)
np.fill_diagonal(corr.values,0)
corr
# Out:
#         AT    AP    AH  AFDP  GTEP   TIT   TAT   TEY   CDP    CO   NOX
# AT    0.00 -0.41 -0.55 -0.10 -0.05  0.09  0.34 -0.21 -0.10 -0.09 -0.60
# AP   -0.41  0.00  0.04  0.04  0.08  0.03 -0.22  0.15  0.13  0.04  0.26
# AH   -0.55  0.04  0.00 -0.12 -0.20 -0.25  0.01 -0.11 -0.18  0.17  0.14
# AFDP -0.10  0.04 -0.12  0.00  0.74  0.63 -0.57  0.72  0.73 -0.33 -0.04
# GTEP -0.05  0.08 -0.20  0.74  0.00  0.87 -0.76  0.98  0.99 -0.51 -0.21
# TIT   0.09  0.03 -0.25  0.63  0.87  0.00 -0.36  0.89  0.89 -0.69 -0.23
# TAT   0.34 -0.22  0.01 -0.57 -0.76 -0.36  0.00 -0.72 -0.74  0.06  0.01
# TEY  -0.21  0.15 -0.11  0.72  0.98  0.89 -0.72  0.00  0.99 -0.54 -0.10
# CDP  -0.10  0.13 -0.18  0.73  0.99  0.89 -0.74  0.99  0.00 -0.52 -0.17
# CO   -0.09  0.04  0.17 -0.33 -0.51 -0.69  0.06 -0.54 -0.52  0.00  0.32
# NOX  -0.60  0.26  0.14 -0.04 -0.21 -0.23  0.01 -0.10 -0.17  0.32  0.00

# %%
plt.figure(figsize=(10,10))
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,annot=True,mask=mask)
plt.show()

# %% [markdown]
# #### There is multi collinearity in the dataset

# %% [markdown]
# ### Data Preparation

# %%
X=gt.drop('TEY',axis=1)
y=gt[['TEY']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=12)

# %%
ss=StandardScaler()
scaled_X_train=ss.fit_transform(X_train)
scaled_X_test=ss.fit_transform(X_test)

# %%
scaled_X_train.shape,scaled_X_test.shape,y_train.shape,y_test.shape
# Out:
# ((10527, 10), (4512, 10), (10527, 1), (4512, 1))

# %% [markdown]
# ### Model Building

# %% [markdown]
# ### CROSS VALIDATION TECHNIQUE

# %%
def basemodel():
    model=Sequential()
    model.add(Dense(units=64,input_dim=10,activation='tanh'))
    model.add(Dense(units=32,activation='relu'))
    model.add(Dense(units=32,activation='relu'))
    model.add(Dense(units=1))
    adam=Adam(learning_rate=0.01)
    model.compile(loss='mean_squared_error',metrics=["mean_squared_error"],optimizer=adam)
    return model

# %%
estimator=KerasRegressor(build_fn=basemodel,verbose=0)
batch_size = [10,20,40,50]
epochs = [10,50,75,100]
param_grid = dict(batch_size=batch_size,epochs=epochs)
grid=GridSearchCV(estimator=estimator,param_grid=param_grid,cv=KFold(),verbose=10)

# %%
grid_results=grid.fit(scaled_X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5; 1/16] START batch_size=10, epochs=10...................................
# [CV 1/5; 1/16] END ....batch_size=10, epochs=10;, score=0.991 total time=  13.5s
# [CV 2/5; 1/16] START batch_size=10, epochs=10...................................
# [CV 2/5; 1/16] END ....batch_size=10, epochs=10;, score=0.994 total time=  14.8s
# [CV 3/5; 1/16] START batch_size=10, epochs=10...................................
# [CV 3/5; 1/16] END ....batch_size=10, epochs=10;, score=0.995 total time=  14.0s
# [CV 4/5; 1/16] START batch_size=10, epochs=10...................................
# [CV 4/5; 1/16] END ....batch_size=10, epochs=10;, score=0.995 total time=  12.0s
# [CV 5/5; 1/16] START batch_size=10, epochs=10...................................
# [CV 5/5; 1/16] END ....batch_size=10, epochs=10;, score=0.946 total time=  11.1s
# [CV 1/5; 2/16] START batch_size=10, epochs=50...................................
# [CV 1/5; 2/16] END ....batch_size=10, epochs=50;, score=0.998 total time=  55.2s
# [CV 2/5; 2/16] START batch_size=10, epochs=50...................................
# [CV 2/5; 2/16] END ....batch_size=10, epochs=50;, score=0.978 total time=  52.7s
# [CV 3/5; 2/16] START batch_size=10, epochs=50...................................
# [CV 3/5; 2/16] END ....batch_size=10, epochs=50;, score=0.995 total time=  53.9s
# [CV 4/5; 2/16] START batch_size=10, epochs=50...................................
# [CV 4/5; 2/16] END ....batch_size=10, epochs=50;, score=0.991 total time=  54.8s
# [CV 5/5; 2/16] START batch_size=10, epochs=50...................................
# [CV 5/5; 2/16] END ....batch_size=10, epochs=50;, score=0.997 total time=  54.5s
# [CV 1/5; 3/16] START batch_size=10, epochs=75...................................
# [CV 1/5; 3/16] END ....batch_size=10, epochs=75;, score=0.997 total time= 1.3min
# [CV 2/5; 3/16] START batch_size=10, epochs=75...................................
# [CV 2/5; 3/16] END ....batch_size=10, epochs=75;, score=0.996 total time= 1.3min
# [CV 3/5; 3/16] START batch_size=10, epochs=75...................................
# [CV 3/5; 3/16] END ....batch_size=10, epochs=75;, score=0.995 total time= 1.3min
# [CV 4/5; 3/16] START batch_size=10, epochs=75...................................
# [CV 4/5; 3/16] END ....batch_size=10, epochs=75;, score=0.998 total time= 1.3min
# [CV 5/5; 3/16] START batch_size=10, epochs=75...................................
# [CV 5/5; 3/16] END ....batch_size=10, epochs=75;, score=0.998 total time= 1.2min
# [CV 1/5; 4/16] START batch_size=10, epochs=100..................................
# [CV 1/5; 4/16] END ...batch_size=10, epochs=100;, score=0.995 total time= 1.7min
# [CV 2/5; 4/16] START batch_size=10, epochs=100..................................
# [CV 2/5; 4/16] END ...batch_size=10, epochs=100;, score=0.996 total time= 1.6min
# [CV 3/5; 4/16] START batch_size=10, epochs=100..................................
# [CV 3/5; 4/16] END ...batch_size=10, epochs=100;, score=0.994 total time= 1.6min
# [CV 4/5; 4/16] START batch_size=10, epochs=100..................................
# [CV 4/5; 4/16] END ...batch_size=10, epochs=100;, score=0.997 total time= 1.5min
# [CV 5/5; 4/16] START batch_size=10, epochs=100..................................
# [CV 5/5; 4/16] END ...batch_size=10, epochs=100;, score=0.998 total time= 1.6min
# [CV 1/5; 5/16] START batch_size=20, epochs=10...................................
# [CV 1/5; 5/16] END ....batch_size=20, epochs=10;, score=0.984 total time=   5.4s
# [CV 2/5; 5/16] START batch_size=20, epochs=10...................................
# [CV 2/5; 5/16] END ....batch_size=20, epochs=10;, score=0.983 total time=   5.7s
# [CV 3/5; 5/16] START batch_size=20, epochs=10...................................
# [CV 3/5; 5/16] END ....batch_size=20, epochs=10;, score=0.981 total time=   5.6s
# [CV 4/5; 5/16] START batch_size=20, epochs=10...................................
# [CV 4/5; 5/16] END ....batch_size=20, epochs=10;, score=0.990 total time=   5.8s
# [CV 5/5; 5/16] START batch_size=20, epochs=10...................................
# [CV 5/5; 5/16] END ....batch_size=20, epochs=10;, score=0.949 total time=   5.5s
# [CV 1/5; 6/16] START batch_size=20, epochs=50...................................
# [CV 1/5; 6/16] END ....batch_size=20, epochs=50;, score=0.998 total time=  24.5s
# [CV 2/5; 6/16] START batch_size=20, epochs=50...................................
# [CV 2/5; 6/16] END ....batch_size=20, epochs=50;, score=0.996 total time=  24.7s
# [CV 3/5; 6/16] START batch_size=20, epochs=50...................................
# [CV 3/5; 6/16] END ....batch_size=20, epochs=50;, score=0.998 total time=  24.8s
# [CV 4/5; 6/16] START batch_size=20, epochs=50...................................
# [CV 4/5; 6/16] END ....batch_size=20, epochs=50;, score=0.996 total time=  28.1s
# [CV 5/5; 6/16] START batch_size=20, epochs=50...................................
# [CV 5/5; 6/16] END ....batch_size=20, epochs=50;, score=0.981 total time=  28.3s
# [CV 1/5; 7/16] START batch_size=20, epochs=75...................................
# [CV 1/5; 7/16] END ....batch_size=20, epochs=75;, score=0.997 total time=  37.2s
# [CV 2/5; 7/16] START batch_size=20, epochs=75...................................
# [CV 2/5; 7/16] END ....batch_size=20, epochs=75;, score=0.988 total time=  38.7s
# [CV 3/5; 7/16] START batch_size=20, epochs=75...................................
# [CV 3/5; 7/16] END ....batch_size=20, epochs=75;, score=0.990 total time=  38.1s
# [CV 4/5; 7/16] START batch_size=20, epochs=75...................................
# [CV 4/5; 7/16] END ....batch_size=20, epochs=75;, score=0.998 total time=  40.4s
# [CV 5/5; 7/16] START batch_size=20, epochs=75...................................
# [CV 5/5; 7/16] END ....batch_size=20, epochs=75;, score=0.998 total time=  38.5s
# [CV 1/5; 8/16] START batch_size=20, epochs=100..................................
# [CV 1/5; 8/16] END ...batch_size=20, epochs=100;, score=0.996 total time=  51.1s
# [CV 2/5; 8/16] START batch_size=20, epochs=100..................................
# [CV 2/5; 8/16] END ...batch_size=20, epochs=100;, score=0.993 total time=  53.1s
# [CV 3/5; 8/16] START batch_size=20, epochs=100..................................
# [CV 3/5; 8/16] END ...batch_size=20, epochs=100;, score=0.995 total time=  49.8s
# [CV 4/5; 8/16] START batch_size=20, epochs=100..................................
# [CV 4/5; 8/16] END ...batch_size=20, epochs=100;, score=0.994 total time=  49.2s
# [CV 5/5; 8/16] START batch_size=20, epochs=100..................................
# [CV 5/5; 8/16] END ...batch_size=20, epochs=100;, score=0.998 total time=  52.1s
# [CV 1/5; 9/16] START batch_size=40, epochs=10...................................
# [CV 1/5; 9/16] END ....batch_size=40, epochs=10;, score=0.997 total time=   3.2s
# [CV 2/5; 9/16] START batch_size=40, epochs=10...................................
# [CV 2/5; 9/16] END ....batch_size=40, epochs=10;, score=0.997 total time=   3.2s
# [CV 3/5; 9/16] START batch_size=40, epochs=10...................................
# [CV 3/5; 9/16] END ....batch_size=40, epochs=10;, score=0.997 total time=   3.8s
# [CV 4/5; 9/16] START batch_size=40, epochs=10...................................
# [CV 4/5; 9/16] END ....batch_size=40, epochs=10;, score=0.996 total time=   3.3s
# [CV 5/5; 9/16] START batch_size=40, epochs=10...................................
# [CV 5/5; 9/16] END ....batch_size=40, epochs=10;, score=0.997 total time=   3.0s
# [CV 1/5; 10/16] START batch_size=40, epochs=50..................................
# [CV 1/5; 10/16] END ...batch_size=40, epochs=50;, score=0.993 total time=  13.6s
# [CV 2/5; 10/16] START batch_size=40, epochs=50..................................
# [CV 2/5; 10/16] END ...batch_size=40, epochs=50;, score=0.993 total time=  14.3s
# [CV 3/5; 10/16] START batch_size=40, epochs=50..................................
# [CV 3/5; 10/16] END ...batch_size=40, epochs=50;, score=0.998 total time=  12.7s
# [CV 4/5; 10/16] START batch_size=40, epochs=50..................................
# [CV 4/5; 10/16] END ...batch_size=40, epochs=50;, score=0.990 total time=  13.6s
# [CV 5/5; 10/16] START batch_size=40, epochs=50..................................
# [CV 5/5; 10/16] END ...batch_size=40, epochs=50;, score=0.989 total time=  13.0s
# [CV 1/5; 11/16] START batch_size=40, epochs=75..................................
# [CV 1/5; 11/16] END ...batch_size=40, epochs=75;, score=0.986 total time=  20.1s
# [CV 2/5; 11/16] START batch_size=40, epochs=75..................................
# [CV 2/5; 11/16] END ...batch_size=40, epochs=75;, score=0.994 total time=  19.0s
# [CV 3/5; 11/16] START batch_size=40, epochs=75..................................
# [CV 3/5; 11/16] END ...batch_size=40, epochs=75;, score=0.998 total time=  18.7s
# [CV 4/5; 11/16] START batch_size=40, epochs=75..................................
# [CV 4/5; 11/16] END ...batch_size=40, epochs=75;, score=0.998 total time=  18.4s
# [CV 5/5; 11/16] START batch_size=40, epochs=75..................................
# [CV 5/5; 11/16] END ...batch_size=40, epochs=75;, score=0.997 total time=  19.2s
# [CV 1/5; 12/16] START batch_size=40, epochs=100.................................
# [CV 1/5; 12/16] END ..batch_size=40, epochs=100;, score=0.997 total time=  24.3s
# [CV 2/5; 12/16] START batch_size=40, epochs=100.................................
# [CV 2/5; 12/16] END ..batch_size=40, epochs=100;, score=0.998 total time=  25.9s
# [CV 3/5; 12/16] START batch_size=40, epochs=100.................................
# [CV 3/5; 12/16] END ..batch_size=40, epochs=100;, score=0.994 total time=  26.2s
# [CV 4/5; 12/16] START batch_size=40, epochs=100.................................
# [CV 4/5; 12/16] END ..batch_size=40, epochs=100;, score=0.998 total time=  26.8s
# [CV 5/5; 12/16] START batch_size=40, epochs=100.................................
# [CV 5/5; 12/16] END ..batch_size=40, epochs=100;, score=0.997 total time=  26.4s
# [CV 1/5; 13/16] START batch_size=50, epochs=10..................................
# [CV 1/5; 13/16] END ...batch_size=50, epochs=10;, score=0.996 total time=   2.6s
# [CV 2/5; 13/16] START batch_size=50, epochs=10..................................
# [CV 2/5; 13/16] END ...batch_size=50, epochs=10;, score=0.996 total time=   3.0s
# [CV 3/5; 13/16] START batch_size=50, epochs=10..................................
# [CV 3/5; 13/16] END ...batch_size=50, epochs=10;, score=0.996 total time=   2.5s
# [CV 4/5; 13/16] START batch_size=50, epochs=10..................................
# [CV 4/5; 13/16] END ...batch_size=50, epochs=10;, score=0.996 total time=   2.6s
# [CV 5/5; 13/16] START batch_size=50, epochs=10..................................
# [CV 5/5; 13/16] END ...batch_size=50, epochs=10;, score=0.997 total time=   2.3s
# [CV 1/5; 14/16] START batch_size=50, epochs=50..................................
# [CV 1/5; 14/16] END ...batch_size=50, epochs=50;, score=0.995 total time=  10.0s
# [CV 2/5; 14/16] START batch_size=50, epochs=50..................................
# [CV 2/5; 14/16] END ...batch_size=50, epochs=50;, score=0.996 total time=  10.4s
# [CV 3/5; 14/16] START batch_size=50, epochs=50..................................
# [CV 3/5; 14/16] END ...batch_size=50, epochs=50;, score=0.997 total time=  10.3s
# [CV 4/5; 14/16] START batch_size=50, epochs=50..................................
# [CV 4/5; 14/16] END ...batch_size=50, epochs=50;, score=0.996 total time=  10.3s
# [CV 5/5; 14/16] START batch_size=50, epochs=50..................................
# [CV 5/5; 14/16] END ...batch_size=50, epochs=50;, score=0.998 total time=  11.0s
# [CV 1/5; 15/16] START batch_size=50, epochs=75..................................
# [CV 1/5; 15/16] END ...batch_size=50, epochs=75;, score=0.993 total time=  16.4s
# [CV 2/5; 15/16] START batch_size=50, epochs=75..................................
# [CV 2/5; 15/16] END ...batch_size=50, epochs=75;, score=0.998 total time=  16.2s
# [CV 3/5; 15/16] START batch_size=50, epochs=75..................................
# [CV 3/5; 15/16] END ...batch_size=50, epochs=75;, score=0.992 total time=  16.9s
# [CV 4/5; 15/16] START batch_size=50, epochs=75..................................
# [CV 4/5; 15/16] END ...batch_size=50, epochs=75;, score=0.998 total time=  19.3s
# [CV 5/5; 15/16] START batch_size=50, epochs=75..................................
# [CV 5/5; 15/16] END ...batch_size=50, epochs=75;, score=0.998 total time=  16.6s
# [CV 1/5; 16/16] START batch_size=50, epochs=100.................................
# [CV 1/5; 16/16] END ..batch_size=50, epochs=100;, score=0.994 total time=  21.5s
# [CV 2/5; 16/16] START batch_size=50, epochs=100.................................
# [CV 2/5; 16/16] END ..batch_size=50, epochs=100;, score=0.997 total time=  20.0s
# [CV 3/5; 16/16] START batch_size=50, epochs=100.................................
# [CV 3/5; 16/16] END ..batch_size=50, epochs=100;, score=0.995 total time=  20.6s
# [CV 4/5; 16/16] START batch_size=50, epochs=100.................................
# [CV 4/5; 16/16] END ..batch_size=50, epochs=100;, score=0.995 total time=  20.1s
# [CV 5/5; 16/16] START batch_size=50, epochs=100.................................
# [CV 5/5; 16/16] END ..batch_size=50, epochs=100;, score=0.997 total time=  20.2s

# %%
grid_results.best_score_
# Out:
# 0.9968022696294303

# %%
grid_results.best_params_
# Out:
# {'batch_size': 40, 'epochs': 10}

# %% [markdown]
# ### Model Building with Best Parameters

# %%
model=Sequential()
model.add(Dense(units=32,activation='relu',input_dim=10))
model.add(Dense(units=64,activation='relu'))
model.add(Dense(units=96,activation='relu'))
model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=64,activation='relu'))
model.add(Dense(units=96,activation='relu'))
model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential_81"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_324 (Dense)           (None, 32)                352
#
#  dense_325 (Dense)           (None, 64)                2112
#
#  dense_326 (Dense)           (None, 96)                6240
#
#  dense_327 (Dense)           (None, 32)                3104
#
#  dense_328 (Dense)           (None, 64)                2112
#
#  dense_329 (Dense)           (None, 96)                6240
#
#  dense_330 (Dense)           (None, 1)                 97
#
# =================================================================
# Total params: 20,257
# Trainable params: 20,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam=Adam(learning_rate=0.01)
model.compile(optimizer=adam,loss='mean_squared_error',metrics=["mean_squared_error"])

# %%
model_history=model.fit(X_train,y_train,epochs=10,batch_size=40,validation_split=0.3)
# Out:
# Epoch 1/10
# 185/185 [==============================] - 1s 3ms/step - loss: 318.3263 - mean_squared_error: 318.3263 - val_loss: 11.3619 - val_mean_squared_error: 11.3619
# Epoch 2/10
# 185/185 [==============================] - 0s 2ms/step - loss: 47.8097 - mean_squared_error: 47.8097 - val_loss: 6.2334 - val_mean_squared_error: 6.2334
# Epoch 3/10
# 185/185 [==============================] - 0s 2ms/step - loss: 13.7509 - mean_squared_error: 13.7509 - val_loss: 6.5259 - val_mean_squared_error: 6.5259
# Epoch 4/10
# 185/185 [==============================] - 0s 2ms/step - loss: 20.2993 - mean_squared_error: 20.2993 - val_loss: 21.6361 - val_mean_squared_error: 21.6361
# Epoch 5/10
# 185/185 [==============================] - 0s 2ms/step - loss: 19.7634 - mean_squared_error: 19.7634 - val_loss: 4.8076 - val_mean_squared_error: 4.8076
# Epoch 6/10
# 185/185 [==============================] - 0s 2ms/step - loss: 7.5686 - mean_squared_error: 7.5686 - val_loss: 29.8413 - val_mean_squared_error: 29.8413
# Epoch 7/10
# 185/185 [==============================] - 0s 2ms/step - loss: 6.6243 - mean_squared_error: 6.6243 - val_loss: 19.5028 - val_mean_squared_error: 19.5028
# Epoch 8/10
# 185/185 [==============================] - 0s 2ms/step - loss: 13.8595 - mean_squared_error: 13.8595 - val_loss: 7.8690 - val_mean_squared_error: 7.8690
# Epoch 9/10
# 185/185 [==============================] - 0s 2ms/step - loss: 11.0335 - mean_squared_error: 11.0335 - val_loss: 44.9805 - val_mean_squared_error: 44.9805
# Epoch 10/10
# 185/185 [==============================] - 0s 2ms/step - loss: 12.8788 - mean_squared_error: 12.8788 - val_loss: 4.1890 - val_mean_squared_error: 4.1890

# %% [markdown]
# ### Model Evaluation

# %%
model.evaluate(X_test,y_test)
# Out:
# 141/141 [==============================] - 0s 1ms/step - loss: 4.1967 - mean_squared_error: 4.1967
# [4.196694850921631, 4.196694850921631]

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %% [markdown]
# ### Model Testing

# %%
y_pred_test=model.predict(X_test)
y_pred_train=model.predict(X_train)
# Out:
# 141/141 [==============================] - 0s 1ms/step
# 329/329 [==============================] - 0s 970us/step

# %% [markdown]
# ### Model Evaluation

# %%
test_predictions=pd.DataFrame()
test_predictions['Actual']=y_test
test_predictions['Predicted']=y_pred_test
test_predictions
# Out:
#        Actual   Predicted
# 4841   112.06  108.185036
# 6730   127.18  123.953636
# 7694   132.70  131.026505
# 9566   159.95  157.952209
# 6017   132.85  130.181793
# ...       ...         ...
# 8007   133.56  131.309113
# 5394   133.73  132.135925
# 14601  112.90  110.907715
# 917    159.87  159.280609
# 6196   119.74  114.237694
#
# [4512 rows x 2 columns]

# %%
train_predictions=pd.DataFrame()
train_predictions['Actual']=y_train
train_predictions['Predicted']=y_pred_train
train_predictions
# Out:
#        Actual   Predicted
# 11629  150.96  147.107590
# 4597   110.78  109.706139
# 4532   134.78  133.610046
# 7531   133.05  129.816345
# 11594  113.18  112.935219
# ...       ...         ...
# 7409   113.45  116.454063
# 3325   132.67  130.456131
# 9606   133.68  131.672913
# 5787   110.04  108.630112
# 14155  162.55  160.436035
#
# [10527 rows x 2 columns]

# %% [markdown]
# ### Model Performance - Training Vs Test Loss

# %%
plt.figure(figsize=(14,6))
plt.plot(model_history.history['loss'],label = 'Training Loss')
plt.plot(model_history.history['val_loss'],label = 'Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Performance - Training Loss Vs Test Loss',size = 20)
plt.legend()
plt.show()

# %% [markdown]
# ### Model Performance - Training Vs Test mean_squared_error

# %%
plt.figure(figsize=(14,6))
plt.plot(model_history.history['mean_squared_error'],label = 'Training mean_squared_error')
plt.plot(model_history.history['val_mean_squared_error'],label = 'Test mean_squared_error')
plt.xlabel('Epochs')
plt.ylabel('mean_squared_error')
plt.title('Model Performance - Training mean_squared_error Vs Test mean_squared_error',size = 20)
plt.legend()
plt.show()

# %%
plt.scatter(y_test,y_pred_test)
plt.show()

# %%
plt.scatter(y_train,y_pred_train)
plt.show()

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 4.213501687716446

# %%
mean_squared_error(y_test,y_pred_test)
# Out:
# 4.196695294181662

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.9832171108163247

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.9831726348105289

# %% [markdown]
# #### R2 score is very high, means our model is doing pretty good job

# %% [markdown]
# ### End !!!
